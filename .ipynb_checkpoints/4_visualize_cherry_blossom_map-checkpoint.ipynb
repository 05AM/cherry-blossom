# %%
import pandas as pd

loc_data_0401 = pd.read_csv('source/cherryblossom_final_20230401.csv',
                     sep=',', engine='python')

loc_data_0402 = pd.read_csv('source/cherryblossom_final_20230402.csv',
                     sep=',', engine='python')

loc_data_0403 = pd.read_csv('source/cherryblossom_final_20230403.csv',
                     sep=',', engine='python')

loc_data_0404 = pd.read_csv('source/cherryblossom_final_20230404.csv',
                     sep=',', engine='python')

loc_data_0405 = pd.read_csv('source/cherryblossom_final_20230405.csv',
                     sep=',', engine='python')

loc_data_0406 = pd.read_csv('source/cherryblossom_final_20230406.csv',
                     sep=',', engine='python')

loc_data_0407 = pd.read_csv('source/cherryblossom_final_20230407.csv',
                     sep=',', engine='python')

# %% [markdown]
# ## 막대 그래프로 시각화

# %%
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc

# encoding
font_path = "C:/Windows/Fonts/NGULIM.TTF"
font = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font)

# 0402
x = loc_data_0402['loc_name']
y = loc_data_0402['user_cnt_day']

plt.figure(figsize=(10, 8))

plt.bar(x, y)

# 그래프 제목과 축 레이블 설정
plt.title('Day(09-16) Exit Traffic 20230402')
plt.xlabel('location')
plt.ylabel('traffic')
plt.xticks(range(len(x)), x, rotation='vertical')

plt.savefig('result/day_exit_traffic_20230402.png')

plt.show()

# %% [markdown]
# ## 지도로 시각화

# %%
# 평일
data_average_weekday = loc_data_0401

data_average_weekday = data_average_weekday.drop('user_cnt_day', axis=1)
data_average_weekday = data_average_weekday.drop('user_cnt_night', axis=1)

# 주말
data_average_weekend = loc_data_0403

data_average_weekend = data_average_weekend.drop('user_cnt_day', axis=1)
data_average_weekend = data_average_weekend.drop('user_cnt_night', axis=1)

# %%
data_average_weekday['average_user_cnt_day'] = (loc_data_0401['user_cnt_day'] + loc_data_0402['user_cnt_day'] + loc_data_0405['user_cnt_day'] + 
loc_data_0406['user_cnt_day'] + loc_data_0407['user_cnt_day']) / 5

data_average_weekday['average_user_cnt_night'] = (loc_data_0401['user_cnt_night'] + loc_data_0402['user_cnt_night'] + loc_data_0405['user_cnt_night'] + 
loc_data_0406['user_cnt_night'] + loc_data_0407['user_cnt_night']) / 5

data_average_weekday
# Out:
#                   loc_name                      address    gu  main_flower  \
# 0             여의 동·서로(윤중로)         서울특별시 영등포구 여의도동 여의서로  영등포구           벚꽃
# 1   올림픽로(광진교 남단 ~ LG전자사거리)           서울특별시 강동구 올림픽로 722   강동구           벚꽃
# 2        벚꽃로(독산역~가산디지털단지역)             서울특별시 금천구 벚꽃로 30   금천구           벚꽃
# 3             송파나루공원(석촌호수)          서울특별시 송파구 석촌호수로 188   송파구  벚꽃, 철쭉, 야생화
# 4                    보라매공원  서울특별시 동작구 여의대방로20길 33 보라매공원   동작구           벚꽃
# 5     안산도시자연공원 (안산문화쉼터벚꽃길)        서울특별시 서대문구 연희로32길 134  서대문구  벚꽃, 철쭉, 개나리
# 6                    경희대학교           서울특별시 동대문구 경희대로 24  동대문구    벚꽃, 개나리 등
# 16                2715.0                  2128.8
# 17                 445.6                   446.6
# 18                1009.0                   898.2
# 19                 428.4                   513.0
# 20                1480.2                  1752.4
# 21                 258.6                   271.6
# 22                 141.2                   138.2

# %%
data_average_weekend['average_user_cnt_day'] = (loc_data_0403['user_cnt_day'] + loc_data_0404['user_cnt_day']) / 2

data_average_weekend['average_user_cnt_night'] = (loc_data_0403['user_cnt_night'] + loc_data_0404['user_cnt_night']) / 2

data_average_weekend
# Out:
#                   loc_name                      address    gu  main_flower  \
# 0             여의 동·서로(윤중로)         서울특별시 영등포구 여의도동 여의서로  영등포구           벚꽃
# 1   올림픽로(광진교 남단 ~ LG전자사거리)           서울특별시 강동구 올림픽로 722   강동구           벚꽃
# 2        벚꽃로(독산역~가산디지털단지역)             서울특별시 금천구 벚꽃로 30   금천구           벚꽃
# 3             송파나루공원(석촌호수)          서울특별시 송파구 석촌호수로 188   송파구  벚꽃, 철쭉, 야생화
# 4                    보라매공원  서울특별시 동작구 여의대방로20길 33 보라매공원   동작구           벚꽃
# 5     안산도시자연공원 (안산문화쉼터벚꽃길)        서울특별시 서대문구 연희로32길 134  서대문구  벚꽃, 철쭉, 개나리
# 6                    경희대학교           서울특별시 동대문구 경희대로 24  동대문구    벚꽃, 개나리 등
# 7                     방화공원           서울특별시 강서구 금낭화로 167   강서구           벚꽃
# 8                 서울숲 벚나무길      서울특별시 성동구 뚝섬로 273 서울숲공원   성동구       벚꽃, 튤립
# 9                      오리로             서울특별시 구로구 경인로 98   구로구           벚꽃
# 10             도구로(도구머리꽃길)           서울특별시 서초구 도구로 45-3   서초구      벚꽃, 개나리
# 11              어린이대공원 산책로            서울특별시 광진구 능동로 216   광진구           벚꽃
# 12     희우정로(양화로11 ~망원정사거리)            서울특별시 마포구 희우정로 66   마포구           벚꽃
# 13                    워커힐길           서울특별시 광진구 광장동 워커힐길   광진구           벚꽃
# 14          도림천(신대방역~시흥대로)              서울특별시 동작구 대림로 2   관악구           벚꽃
# 15          경의선숲길(공덕역~대흥역)         서울특별시 마포구 백범로36길 8-7   마포구           벚꽃
# 16                남산공원 순환로           서울특별시 중구 남산공원길 507    중구         벚꽃 등
# 17       성내천 둔치(위례성길~복개종점)             서울특별시 송파구 성내천로 6   송파구           벚꽃
# 18                    양재천변            서울특별시 서초구 양재동 양재천   서초구    개나리, 벚꽃 등
# 19                  경춘선 숲길          서울특별시 노원구 화랑로51가길 3   노원구           벚꽃
# 20         북서울 꿈의 숲 월영지 주변   서울특별시 강북구 월계로 173 북서울 꿈의 숲   강북구           벚꽃
# 21         안양천 제방(신정교~양평교)   서울특별시 영등포구 양평동 487 안양천 제방길  영등포구  벚꽃, 개나리, 철쭉
# 22          중랑천제방(공원녹지순환길)   서울특별시 중랑구 중화동 410-11 중랑천제방  동대문구    벚꽃, 개나리 등
#
#       season length                                            feature  \
# 0    3월말~4월중   6.9㎞  여의도 국회주변 화려한 벚꽃이 장관을 이루며 매년 ‘한강 여의도 봄꽃축제’ 개최(나...
# 9         133000           온수역         1          145  37.491452  126.833079
# 10        116000           사당역        13          226  37.480717  126.988219
# 11        107000          아차산역         4          545  37.549589  127.081578
# 12         96800           망원역         2          621  37.552306  126.904843
# 13         50600          광나루역         1          546  37.551900  127.105930
# 14         48800          신대방역         4          231  37.487549  126.912960
# 15         29800           공덕역         1          529  37.543646  126.949024
# 16         23100           명동역         1          424  37.553947  126.989913
# 17         20600           방이역         1         P551  37.507572  127.135425
# 18         19400       양재시민의숲역         1          D09  37.470278  127.030833
# 19         17800          화랑대역         1          646  37.623678  127.090023
# 20         17700        미아사거리역         1          416  37.621431  127.040625
# 21         10800           양평역         1          522  37.529080  126.887949
# 22         10600          외대앞역         3          122  37.584173  127.075348
#
#     average_user_cnt_day  average_user_cnt_night
# 0                 7775.0                  8569.0
# 1                 1046.0                   710.5
# 2                 3501.5                  2424.0
# 3                 5327.0                  5869.0
# 4                  142.5                    58.0
# 5                 2102.0                  1229.0
# 6                 8408.5                  5409.5
# 7                  121.5                    51.0
# 8                  869.5                   524.0
# 9                  629.5                   420.0
# 10                4637.5                  3741.0
# 11                 374.5                   175.0
# 12                4697.5                  3492.5
# 13                2840.5                  1209.5
# 14                1065.5                   661.5
# 15                 862.0                   511.5
# 16                2355.0                  1398.5
# 17                 474.0                   306.5
# 18                1215.0                   552.0
# 19                 454.0                   290.5
# 20                1503.5                  1041.5
# 21                 203.0                   127.0
# 22                 131.5                    77.0

# %% [markdown]
# ## 막대 그래프로 시각화

# %% [markdown]
# ### 평일 밤

# %%
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc

# encoding
font_path = "C:/Windows/Fonts/NGULIM.TTF"
font = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font)

data_average_weekday = data_average_weekday.sort_values(by='average_user_cnt_night', ascending=False)

x = data_average_weekday['loc_name']
y = data_average_weekday['average_user_cnt_night']

plt.figure(figsize=(10, 8))

plt.bar(x, y)

# 그래프 제목과 축 레이블 설정
plt.title('평일 밤(17-23)')
plt.xlabel('location')
plt.ylabel('traffic')
plt.xticks(range(len(x)), x, rotation='vertical')

plt.savefig('result/day_exit_traffic_weekday_day.png')

plt.show()

# %% [markdown]
# ### 주말 밤

# %%
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc

# encoding
font_path = "C:/Windows/Fonts/NGULIM.TTF"
font = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font)

data_average_weekend = data_average_weekend.sort_values(by='average_user_cnt_night', ascending=False)

x = data_average_weekend['loc_name']
y = data_average_weekend['average_user_cnt_night']

plt.figure(figsize=(10, 8))

plt.bar(x, y)

# 그래프 제목과 축 레이블 설정
plt.title('주말 밤(17-23)')
plt.xlabel('location')
plt.ylabel('traffic')
plt.xticks(range(len(x)), x, rotation='vertical')

plt.savefig('result/day_exit_traffic_weekend_night.png')

plt.show()

# %% [markdown]
# ## 평일 낮

# %%
import folium

map = folium.Map(
    location=[37.559819, 126.963895],
    zoom_start=12, 
#     tiles='cartodbpositron'
)

for index, row in data_average_weekday.iterrows():
    lat = row['lat']
    long = row['long']
    folium.CircleMarker([lat, long], 
                       radius = row['average_user_cnt_day']/400 + 10,
                       popup = row['loc_name'],
                       color = "red",
                       fill = True).add_to(map)
    
map.save('result/map_cherry_blossom_weekday_day.html')

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0f395af0159739b395885c4dcce46191 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0f395af0159739b395885c4dcce46191&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0f395af0159739b395885c4dcce46191 = L.map(
#                 &quot;map_0f395af0159739b395885c4dcce46191&quot;,
#                 {
#                     center: [37.559819, 126.963895],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bffa44a3fc1ec0840a6d453897f76f97 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_0f395af0159739b395885c4dcce46191);
#
#
#             var circle_marker_66c6aaca32ad11dad155539765583843 = L.circleMarker(
#                 [37.533100700000006, 126.9199973],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 18.4565, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_0f395af0159739b395885c4dcce46191);
#
#
#         var popup_a6eaa987abbc2e2b40e925bf0cc54093 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_bafa6b0aefba6f25b7b441fc5fd021b5 = $(`&lt;div id=&quot;html_bafa6b0aefba6f25b7b441fc5fd021b5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;여의 동·서로(윤중로)&lt;/div&gt;`)[0];
#                 popup_a6eaa987abbc2e2b40e925bf0cc54093.setContent(html_bafa6b0aefba6f25b7b441fc5fd021b5);
#
#
#
#         circle_marker_66c6aaca32ad11dad155539765583843.bindPopup(popup_a6eaa987abbc2e2b40e925bf0cc54093)
#         ;
#
#
#
#
#             var circle_marker_f6a3386044635ca7b43ea336e0dd16f3 = L.circleMarker(
#                 [37.5456749, 127.1262186],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 13.025, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_0f395af0159739b395885c4dcce46191);
#
#
#         var popup_91bb32608ff34480c470aa6804170995 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_42dc581228cf64f006ab29ebbfdf24bc = $(`&lt;div id=&quot;html_42dc581228cf64f006ab29ebbfdf24bc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;올림픽로(광진교 남단 ~ LG전자사거리)&lt;/div&gt;`)[0];
#                 popup_91bb32608ff34480c470aa6804170995.setContent(html_42dc581228cf64f006ab29ebbfdf24bc);
#
#
#
#         circle_marker_f6a3386044635ca7b43ea336e0dd16f3.bindPopup(popup_91bb32608ff34480c470aa6804170995)
#         ;
#
#
#
#
#             var circle_marker_9a668d07b18e0ff786277a5d6a7a3c5a = L.circleMarker(
#                 [37.4582394, 126.89417659999998],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 18.130499999999998, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_0f395af0159739b395885c4dcce46191);
#
#
#         var popup_99a33d8c4cd6b041daacf540df8473f5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6bb1a724fa61576d29b53e48b31b9962 = $(`&lt;div id=&quot;html_6bb1a724fa61576d29b53e48b31b9962&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;벚꽃로(독산역~가산디지털단지역)&lt;/div&gt;`)[0];
#                 popup_99a33d8c4cd6b041daacf540df8473f5.setContent(html_6bb1a724fa61576d29b53e48b31b9962);
#
#
#
#         circle_marker_9a668d07b18e0ff786277a5d6a7a3c5a.bindPopup(popup_99a33d8c4cd6b041daacf540df8473f5)
#         ;
#
#
#
#
#             var circle_marker_2a8a267cd9a05104f2f91f61ad236f7b = L.circleMarker(
#                 [37.506240600000005, 127.09771629999999],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;da

# %% [markdown]
# ## 평일 밤

# %%
import folium

map = folium.Map(
    location=[37.559819, 126.963895],
    zoom_start=12, 
#     tiles='cartodbpositron'
)

for index, row in data_average_weekday.iterrows():
    lat = row['lat']
    long = row['long']
    folium.CircleMarker([lat, long], 
                       radius = row['average_user_cnt_night']/400 + 10,
                       popup = row['loc_name'],
                       color = "blue",
                       fill = True).add_to(map)
    
map.save('result/map_cherry_blossom_weekday_night.html')

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8a025f7cc6c393e0a57ec95e5948ca8a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8a025f7cc6c393e0a57ec95e5948ca8a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8a025f7cc6c393e0a57ec95e5948ca8a = L.map(
#                 &quot;map_8a025f7cc6c393e0a57ec95e5948ca8a&quot;,
#                 {
#                     center: [37.559819, 126.963895],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cc8a4a512b5e2321f475ce64e4662bf7 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_8a025f7cc6c393e0a57ec95e5948ca8a);
#
#
#             var circle_marker_ce0aa047dd91777f8d291aba5d13d0ae = L.circleMarker(
#                 [37.533100700000006, 126.9199973],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 20.255499999999998, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_8a025f7cc6c393e0a57ec95e5948ca8a);
#
#
#         var popup_62b1552f65df17d393fa6ce678f4e68f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_106d5a4422f590b2934f02e0edd2b23f = $(`&lt;div id=&quot;html_106d5a4422f590b2934f02e0edd2b23f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;여의 동·서로(윤중로)&lt;/div&gt;`)[0];
#                 popup_62b1552f65df17d393fa6ce678f4e68f.setContent(html_106d5a4422f590b2934f02e0edd2b23f);
#
#
#
#         circle_marker_ce0aa047dd91777f8d291aba5d13d0ae.bindPopup(popup_62b1552f65df17d393fa6ce678f4e68f)
#         ;
#
#
#
#
#             var circle_marker_ddcc2800bc8a4e232d68cbe2d907b11b = L.circleMarker(
#                 [37.5456749, 127.1262186],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 13.1765, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_8a025f7cc6c393e0a57ec95e5948ca8a);
#
#
#         var popup_6ca115376d9b2e2bc6ec44dbd3b51a32 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8d0f4ff42b014c0e87a267355e8d0b08 = $(`&lt;div id=&quot;html_8d0f4ff42b014c0e87a267355e8d0b08&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;올림픽로(광진교 남단 ~ LG전자사거리)&lt;/div&gt;`)[0];
#                 popup_6ca115376d9b2e2bc6ec44dbd3b51a32.setContent(html_8d0f4ff42b014c0e87a267355e8d0b08);
#
#
#
#         circle_marker_ddcc2800bc8a4e232d68cbe2d907b11b.bindPopup(popup_6ca115376d9b2e2bc6ec44dbd3b51a32)
#         ;
#
#
#
#
#             var circle_marker_4f59695749ebf98a6a155b29eaf42b50 = L.circleMarker(
#                 [37.4582394, 126.89417659999998],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 18.8205, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_8a025f7cc6c393e0a57ec95e5948ca8a);
#
#
#         var popup_29ad52baa44335eca168a5aa239f1f13 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2cdaf9eef33019dc60227d7e32dd7e3a = $(`&lt;div id=&quot;html_2cdaf9eef33019dc60227d7e32dd7e3a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;벚꽃로(독산역~가산디지털단지역)&lt;/div&gt;`)[0];
#                 popup_29ad52baa44335eca168a5aa239f1f13.setContent(html_2cdaf9eef33019dc60227d7e32dd7e3a);
#
#
#
#         circle_marker_4f59695749ebf98a6a155b29eaf42b50.bindPopup(popup_29ad52baa44335eca168a5aa239f1f13)
#         ;
#
#
#
#
#             var circle_marker_efc245cfae2be9bdb42c0f468287dd91 = L.circleMarker(
#                 [37.506240600000005, 127.09771629999999],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;,

# %% [markdown]
# ## 주말 낮

# %%
import folium

map = folium.Map(
    location=[37.559819, 126.963895],
    zoom_start=12, 
#     tiles='cartodbpositron'
)

for index, row in data_average_weekend.iterrows():
    lat = row['lat']
    long = row['long']
    folium.CircleMarker([lat, long], 
                       radius = row['average_user_cnt_day']/400 + 10,
                       popup = row['loc_name'],
                       color = "red",
                       fill = True).add_to(map)
    
map.save('result/map_cherry_blossom_weekend_day.html')

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_411aba00a4f42b60ad788d84e83ae0ad {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_411aba00a4f42b60ad788d84e83ae0ad&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_411aba00a4f42b60ad788d84e83ae0ad = L.map(
#                 &quot;map_411aba00a4f42b60ad788d84e83ae0ad&quot;,
#                 {
#                     center: [37.559819, 126.963895],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2ad59f628fbffdaa3c9b0194ba8d3acb = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_411aba00a4f42b60ad788d84e83ae0ad);
#
#
#             var circle_marker_35de41fbf9c1b08e9ba0b904857439af = L.circleMarker(
#                 [37.533100700000006, 126.9199973],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 29.4375, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_411aba00a4f42b60ad788d84e83ae0ad);
#
#
#         var popup_ee0b2d79cd47374581a1d5294d199bd9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_451f47a13fbb93291159a91b67926410 = $(`&lt;div id=&quot;html_451f47a13fbb93291159a91b67926410&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;여의 동·서로(윤중로)&lt;/div&gt;`)[0];
#                 popup_ee0b2d79cd47374581a1d5294d199bd9.setContent(html_451f47a13fbb93291159a91b67926410);
#
#
#
#         circle_marker_35de41fbf9c1b08e9ba0b904857439af.bindPopup(popup_ee0b2d79cd47374581a1d5294d199bd9)
#         ;
#
#
#
#
#             var circle_marker_4075c06c242640b247f209021592b74a = L.circleMarker(
#                 [37.5456749, 127.1262186],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 12.615, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_411aba00a4f42b60ad788d84e83ae0ad);
#
#
#         var popup_f87814075b92332cd0fde1095eb600e0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a99e50ce1370bdd7ad7d5eefd114a57f = $(`&lt;div id=&quot;html_a99e50ce1370bdd7ad7d5eefd114a57f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;올림픽로(광진교 남단 ~ LG전자사거리)&lt;/div&gt;`)[0];
#                 popup_f87814075b92332cd0fde1095eb600e0.setContent(html_a99e50ce1370bdd7ad7d5eefd114a57f);
#
#
#
#         circle_marker_4075c06c242640b247f209021592b74a.bindPopup(popup_f87814075b92332cd0fde1095eb600e0)
#         ;
#
#
#
#
#             var circle_marker_177b90112ea44737327aa5d2139c32b1 = L.circleMarker(
#                 [37.4582394, 126.89417659999998],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 18.75375, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_411aba00a4f42b60ad788d84e83ae0ad);
#
#
#         var popup_161534e17d176536fc32c2b46ffebfcd = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b168479cf0f3b6ec1eb4e501c26cb369 = $(`&lt;div id=&quot;html_b168479cf0f3b6ec1eb4e501c26cb369&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;벚꽃로(독산역~가산디지털단지역)&lt;/div&gt;`)[0];
#                 popup_161534e17d176536fc32c2b46ffebfcd.setContent(html_b168479cf0f3b6ec1eb4e501c26cb369);
#
#
#
#         circle_marker_177b90112ea44737327aa5d2139c32b1.bindPopup(popup_161534e17d176536fc32c2b46ffebfcd)
#         ;
#
#
#
#
#             var circle_marker_afab2e79c9e37724ca0af3c95795ee09 = L.circleMarker(
#                 [37.506240600000005, 127.09771629999999],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&qu

# %% [markdown]
# ## 주말 밤

# %%
import folium

map = folium.Map(
    location=[37.559819, 126.963895],
    zoom_start=12, 
#     tiles='cartodbpositron'
)

for index, row in data_average_weekend.iterrows():
    lat = row['lat']
    long = row['long']
    folium.CircleMarker([lat, long], 
                       radius = row['average_user_cnt_night']/400 + 10,
                       popup = row['loc_name'],
                       color = "blue",
                       fill = True).add_to(map)
    
map.save('result/map_cherry_blossom_weekend_night.html')

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d44e21a380126c883029562ab17f3611 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d44e21a380126c883029562ab17f3611&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d44e21a380126c883029562ab17f3611 = L.map(
#                 &quot;map_d44e21a380126c883029562ab17f3611&quot;,
#                 {
#                     center: [37.559819, 126.963895],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2aab08566a16b19e8e4b637b9df5c29a = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_d44e21a380126c883029562ab17f3611);
#
#
#             var circle_marker_937f5aaa9571414957e9a7abb6b61536 = L.circleMarker(
#                 [37.533100700000006, 126.9199973],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 31.4225, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_d44e21a380126c883029562ab17f3611);
#
#
#         var popup_10745242eb4c83accfe4aee939b16139 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_614f280b16ba6de087c801491d521f0e = $(`&lt;div id=&quot;html_614f280b16ba6de087c801491d521f0e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;여의 동·서로(윤중로)&lt;/div&gt;`)[0];
#                 popup_10745242eb4c83accfe4aee939b16139.setContent(html_614f280b16ba6de087c801491d521f0e);
#
#
#
#         circle_marker_937f5aaa9571414957e9a7abb6b61536.bindPopup(popup_10745242eb4c83accfe4aee939b16139)
#         ;
#
#
#
#
#             var circle_marker_953d7cc7dd58d298fbf948851e58884e = L.circleMarker(
#                 [37.5456749, 127.1262186],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 11.776250000000001, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_d44e21a380126c883029562ab17f3611);
#
#
#         var popup_d65f14721a0482527ba78a9302c5742e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_53df382565f926b907e377072c839d21 = $(`&lt;div id=&quot;html_53df382565f926b907e377072c839d21&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;올림픽로(광진교 남단 ~ LG전자사거리)&lt;/div&gt;`)[0];
#                 popup_d65f14721a0482527ba78a9302c5742e.setContent(html_53df382565f926b907e377072c839d21);
#
#
#
#         circle_marker_953d7cc7dd58d298fbf948851e58884e.bindPopup(popup_d65f14721a0482527ba78a9302c5742e)
#         ;
#
#
#
#
#             var circle_marker_fca9bb7a97c681fb0037cb664628b14c = L.circleMarker(
#                 [37.4582394, 126.89417659999998],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 16.06, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_d44e21a380126c883029562ab17f3611);
#
#
#         var popup_44c4c65b69850e34e6d53d8841a6d6c8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a64923bd680e1f735fe36c55fd00ed7e = $(`&lt;div id=&quot;html_a64923bd680e1f735fe36c55fd00ed7e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;벚꽃로(독산역~가산디지털단지역)&lt;/div&gt;`)[0];
#                 popup_44c4c65b69850e34e6d53d8841a6d6c8.setContent(html_a64923bd680e1f735fe36c55fd00ed7e);
#
#
#
#         circle_marker_fca9bb7a97c681fb0037cb664628b14c.bindPopup(popup_44c4c65b69850e34e6d53d8841a6d6c8)
#         ;
#
#
#
#
#             var circle_marker_01491138b791e995239d51f498dcf432 = L.circleMarker(
#                 [37.506240600000005, 127.09771629999999],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &q
