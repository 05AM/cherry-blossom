# %%
import pandas as pd

loc_data_0401 = pd.read_csv('source/cherryblossom_final_20230401.csv',
                     sep=',', engine='python')

loc_data_0402 = pd.read_csv('source/cherryblossom_final_20230402.csv',
                     sep=',', engine='python')

loc_data_0403 = pd.read_csv('source/cherryblossom_final_20230403.csv',
                     sep=',', engine='python')

loc_data_0404 = pd.read_csv('source/cherryblossom_final_20230404.csv',
                     sep=',', engine='python')

loc_data_0405 = pd.read_csv('source/cherryblossom_final_20230405.csv',
                     sep=',', engine='python')

loc_data_0406 = pd.read_csv('source/cherryblossom_final_20230406.csv',
                     sep=',', engine='python')

loc_data_0407 = pd.read_csv('source/cherryblossom_final_20230407.csv',
                     sep=',', engine='python')

# %% [markdown]
# ## 낮, 밤 통행량 평균 구하기

# %%
# 평일
data_average_weekday = loc_data_0401

data_average_weekday = data_average_weekday.drop('user_cnt_day', axis=1)
data_average_weekday = data_average_weekday.drop('user_cnt_night', axis=1)

# 주말
data_average_weekend = loc_data_0403

data_average_weekend = data_average_weekend.drop('user_cnt_day', axis=1)
data_average_weekend = data_average_weekend.drop('user_cnt_night', axis=1)

# %%
data_average_weekday['average_user_cnt_day'] = (loc_data_0401['user_cnt_day'] + loc_data_0402['user_cnt_day'] + loc_data_0405['user_cnt_day'] + 
loc_data_0406['user_cnt_day'] + loc_data_0407['user_cnt_day']) / 5

data_average_weekday['average_user_cnt_night'] = (loc_data_0401['user_cnt_night'] + loc_data_0402['user_cnt_night'] + loc_data_0405['user_cnt_night'] + 
loc_data_0406['user_cnt_night'] + loc_data_0407['user_cnt_night']) / 5

data_average_weekday
# Out:
#                   loc_name                      address    gu  main_flower  \
# 0             여의 동·서로(윤중로)         서울특별시 영등포구 여의도동 여의서로  영등포구           벚꽃
# 1   올림픽로(광진교 남단 ~ LG전자사거리)           서울특별시 강동구 올림픽로 722   강동구           벚꽃
# 2        벚꽃로(독산역~가산디지털단지역)             서울특별시 금천구 벚꽃로 30   금천구           벚꽃
# 3             송파나루공원(석촌호수)          서울특별시 송파구 석촌호수로 188   송파구  벚꽃, 철쭉, 야생화
# 4                    보라매공원  서울특별시 동작구 여의대방로20길 33 보라매공원   동작구           벚꽃
# 5     안산도시자연공원 (안산문화쉼터벚꽃길)        서울특별시 서대문구 연희로32길 134  서대문구  벚꽃, 철쭉, 개나리
# 6                     방화공원           서울특별시 강서구 금낭화로 167   강서구           벚꽃
# 7                 서울숲 벚나무길      서울특별시 성동구 뚝섬로 273 서울숲공원   성동구       벚꽃, 튤립
# 8                      오리로             서울특별시 구로구 경인로 98   구로구           벚꽃
# 9              도구로(도구머리꽃길)           서울특별시 서초구 도구로 45-3   서초구      벚꽃, 개나리
# 10              어린이대공원 산책로            서울특별시 광진구 능동로 216   광진구           벚꽃
# 11     희우정로(양화로11 ~망원정사거리)            서울특별시 마포구 희우정로 66   마포구           벚꽃
# 12                    워커힐길           서울특별시 광진구 광장동 워커힐길   광진구           벚꽃
# 17   4월초～4월말   2.5㎞                   하천변 산책로를 따라 봄꽃을 감상할 수 있음(산책, 운동)
# 18  3월말~4월중순  0.4km                             철길을 따라 아름다운 벚꽃길 연출(산책)
# 19   4월중~4월말  4.0km      연분홍색의 벚꽃이 월영지, 월광폭포와 어울려 아름다운 경관을 제공(나들이, 산책)
# 20   3월말~4월중   3.0㎞   안양천을 따라 산책로가 조성되어 있고 산책로변으로 꽃이 아름다움(나들이, 산책, 운동)
# 21   4월초~4월중   3.0㎞                   공원녹지 순환길을 따라 아름다운 벚꽃길 연출(산책, 운동)
#
#     result_stats final_station  exit_num station_code        lat        long  \
# 0        1360000        국회의사당역         2          914  37.533101  126.919997
# 1        1230000           천호역         3          547  37.545675  127.126219
# 2         980000         금천구청역         1         P144  37.458239  126.894177
# 3         687000           잠실역         3          216  37.506241  127.097716
# 4         401000          보라매역         1          742  37.493234  126.919712
# 5         363000          무악재역         4          325  37.579483  126.938002
# 6         245000           방화역         4          510  37.580753  126.812542
# 7         135000           뚝섬역         7          210  37.544388  127.037442
# 8         133000           온수역         1          145  37.491452  126.833079
# 9         116000           사당역        13          226  37.480717  126.988219
# 10        107000          아차산역         4          545  37.549589  127.081578
# 11         96800           망원역         2          621  37.552306  126.904843
# 12         50600          광나루역         1          546  37.551900  127.105930
# 13         48800          신대방역         4          231  37.487549  126.912960
# 14         29800           공덕역         1          529  37.543646  126.949024
# 15         23100           명동역         1          424  37.553947  126.989913
# 16         20600           방이역         1         P551  37.507572  127.135425
# 17         19400       양재시민의숲역         1          D09  37.470278  127.030833
# 18         17800          화랑대역         1          646  37.623678  127.090023
# 19         17700        미아사거리역         1          416  37.621431  127.040625
# 20         10800           양평역         1          522  37.529080  126.887949
# 21         10600          외대앞역         3          122  37.584173  127.075348
#
#     average_user_cnt_day  average_user_cnt_night
# 0                 3382.6                  4102.2
# 1                 1210.0                  1270.6
# 2                 3252.2                  3528.2
# 3                 4004.2                  4884.4
# 4                  133.8                   149.4
# 5                 1915.2                  2000.2
# 6                  101.6                    66.0
# 7                  855.4                   829.8
# 8                  864.0                  1060.0
# 9                 3903.2                  4590.2
# 10                 490.0                   470.6
# 11                3826.6                  3672.2
# 12                2406.4                  1812.8
# 13                1082.0                  1043.4
# 14                1233.6                  1309.0
# 15                2715.0                  2128.8
# 16                 445.6                   446.6
# 17                1009.0                   898.2
# 18                 428.4                   513.0
# 19                1480.2                  1752.4
# 20                 258.6                   271.6
# 21                 141.2                   138.2

# %%
data_average_weekend['average_user_cnt_day'] = (loc_data_0403['user_cnt_day'] + loc_data_0404['user_cnt_day']) / 2

data_average_weekend['average_user_cnt_night'] = (loc_data_0403['user_cnt_night'] + loc_data_0404['user_cnt_night']) / 2

data_average_weekend
# Out:
#                   loc_name                      address    gu  main_flower  \
# 0             여의 동·서로(윤중로)         서울특별시 영등포구 여의도동 여의서로  영등포구           벚꽃
# 1   올림픽로(광진교 남단 ~ LG전자사거리)           서울특별시 강동구 올림픽로 722   강동구           벚꽃
# 2                 3501.5                  2424.0
# 3                 5327.0                  5869.0
# 4                  142.5                    58.0
# 5                 2102.0                  1229.0
# 6                  121.5                    51.0
# 7                  869.5                   524.0
# 8                  629.5                   420.0
# 9                 4637.5                  3741.0
# 10                 374.5                   175.0
# 11                4697.5                  3492.5
# 12                2840.5                  1209.5
# 13                1065.5                   661.5
# 14                 862.0                   511.5
# 15                2355.0                  1398.5
# 16                 474.0                   306.5
# 17                1215.0                   552.0
# 18                 454.0                   290.5
# 19                1503.5                  1041.5
# 20                 203.0                   127.0
# 21                 131.5                    77.0

# %% [markdown]
# ## 막대 그래프로 시각화

# %%
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc
import numpy as np

# encoding
font_path = "C:/Windows/Fonts/NGULIM.TTF"
font = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font)

data_average_weekday = data_average_weekday.sort_values(by='average_user_cnt_day', ascending=False)

x = data_average_weekday['loc_name']
y1 = data_average_weekday['average_user_cnt_day']
y2 = data_average_weekday['result_stats']/150

categories = x

plt.figure(figsize=(10, 8))

# 막대 그래프 그리기
bar_width = 0.35
index = np.arange(len(categories))

plt.bar(index, y1, width=bar_width, label='평균 통행량')
plt.bar(index + bar_width, y2, width=bar_width, label='인지도')

# 그래프 제목 및 레이블 설정
plt.title('평일 낮 통행량과 인지도 그래프')
plt.xlabel('장소명')
plt.ylabel('값')
plt.xticks(index + bar_width / 2, categories, rotation='vertical')
plt.legend()

# 그래프 출력
plt.tight_layout()
plt.show()

# %%
### 평일 낮 vs 평일 밤

# %%
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc

# encoding
font_path = "C:/Windows/Fonts/NGULIM.TTF"
font = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font)

data_average_weekday = data_average_weekday.sort_values(by='average_user_cnt_day', ascending=False)

x = data_average_weekday['loc_name']
y1 = data_average_weekday['average_user_cnt_day']
y2 = data_average_weekday['average_user_cnt_night']

plt.figure(figsize=(10, 8))

plt.bar(x, y2)
plt.bar(x, y1)

# 그래프 제목과 축 레이블 설정
plt.title('평일 낮(9-16)', fontsize=16)
plt.xlabel('location')
plt.ylabel('traffic')
plt.xticks(range(len(x)), x, rotation='vertical')

plt.savefig('result/day_exit_traffic_weekday_day_vs_night.png')

plt.show()

# %% [markdown]
# ### 평일 낮

# %%
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc

# encoding
font_path = "C:/Windows/Fonts/NGULIM.TTF"
font = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font)

data_average_weekday = data_average_weekday.sort_values(by='average_user_cnt_day', ascending=False)

x = data_average_weekday['loc_name']
y = data_average_weekday['average_user_cnt_day']

plt.figure(figsize=(10, 8))

plt.bar(x, y)

# 그래프 제목과 축 레이블 설정
plt.title('평일 낮(9-16)', fontsize=16)
plt.xlabel('location')
plt.ylabel('traffic')
plt.xticks(range(len(x)), x, rotation='vertical')

plt.savefig('result/day_exit_traffic_weekday_day.png')

plt.show()

# %% [markdown]
# ### 평일 밤

# %%
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc

# encoding
font_path = "C:/Windows/Fonts/NGULIM.TTF"
font = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font)

data_average_weekday = data_average_weekday.sort_values(by='average_user_cnt_night', ascending=False)

x = data_average_weekday['loc_name']
y = data_average_weekday['average_user_cnt_night']

plt.figure(figsize=(10, 8))

plt.bar(x, y)

# 그래프 제목과 축 레이블 설정
plt.title('평일 밤(17-23)', fontsize=16)
plt.xlabel('location')
plt.ylabel('traffic')
plt.xticks(range(len(x)), x, rotation='vertical')

plt.savefig('result/day_exit_traffic_weekday_night.png')

plt.show()

# %% [markdown]
# ### 주말 낮

# %%
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc

# encoding
font_path = "C:/Windows/Fonts/NGULIM.TTF"
font = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font)

data_average_weekend = data_average_weekend.sort_values(by='average_user_cnt_night', ascending=False)

x = data_average_weekend['loc_name']
y = data_average_weekend['average_user_cnt_night']

plt.figure(figsize=(10, 8))

plt.bar(x, y)

# 그래프 제목과 축 레이블 설정
plt.title('주말 낮(9-16)', fontsize=16)
plt.xlabel('location')
plt.ylabel('traffic')
plt.xticks(range(len(x)), x, rotation='vertical')

plt.savefig('result/day_exit_traffic_weekend_day.png')

plt.show()

# %% [markdown]
# ### 주말 밤

# %%
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc

# encoding
font_path = "C:/Windows/Fonts/NGULIM.TTF"
font = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font)

data_average_weekend = data_average_weekend.sort_values(by='average_user_cnt_night', ascending=False)

x = data_average_weekend['loc_name']
y = data_average_weekend['average_user_cnt_night']

plt.figure(figsize=(10, 8))

plt.bar(x, y)

# 그래프 제목과 축 레이블 설정
plt.title('주말 밤(17-23)', fontsize=16)
plt.xlabel('location')
plt.ylabel('traffic')
plt.xticks(range(len(x)), x, rotation='vertical')

plt.savefig('result/day_exit_traffic_weekend_night.png')

plt.show()

# %% [markdown]
# ## 지도로 시각화

# %% [markdown]
# ### 평일 낮

# %%
import folium

map = folium.Map(
    location=[37.534272313844, 126.97534763076],
    zoom_start=12, 
#     tiles='cartodbpositron'
)

for index, row in data_average_weekday.iterrows():
    lat = row['lat']
    long = row['long']
    folium.CircleMarker([lat, long], 
                       radius = row['average_user_cnt_day']/100 + 5,
                       popup = folium.Popup("<b>{}</b><br><br>- 길이 : {}<br>- {} {}번출구<br>- {}".format(row['loc_name'], row['length'], row['final_station'], row['exit_num'], row['feature']), max_width=300, min_width=150),
                       color = "red",
                       fill = True).add_to(map)
    
map.save('result/map_cherry_blossom_weekday_day.html')

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_711b939505f44d2af8a91765b7005a05 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_711b939505f44d2af8a91765b7005a05&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_711b939505f44d2af8a91765b7005a05 = L.map(
#                 &quot;map_711b939505f44d2af8a91765b7005a05&quot;,
#                 {
#                     center: [37.534272313844, 126.97534763076],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c7944eb98a34cb7b99c7327c98ae0f0d = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_711b939505f44d2af8a91765b7005a05);
#
#
#             var circle_marker_1f538d3ec9b242a1f80860bac27080e0 = L.circleMarker(
#                 [37.506240600000005, 127.09771629999999],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 45.042, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_711b939505f44d2af8a91765b7005a05);
#
#
#         var popup_0c11384e728a69fd4cca498a0c83bc63 = L.popup({&quot;maxWidth&quot;: 300, &quot;minWidth&quot;: 150});
#
#
#
#                 var html_2b12c1f3ea187d5dc900d8ec93f7a6f3 = $(`&lt;div id=&quot;html_2b12c1f3ea187d5dc900d8ec93f7a6f3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;송파나루공원(석촌호수)&lt;/b&gt;&lt;br&gt;&lt;br&gt;- 길이 : 2.5km&lt;br&gt;- 잠실역 3번출구&lt;br&gt;- 석촌호수와 어우러져 피는 벚꽃, 철쭉, 야생화가 아름다움(산책, 운동)&lt;/div&gt;`)[0];
#                 popup_0c11384e728a69fd4cca498a0c83bc63.setContent(html_2b12c1f3ea187d5dc900d8ec93f7a6f3);
#
#
#
#         circle_marker_1f538d3ec9b242a1f80860bac27080e0.bindPopup(popup_0c11384e728a69fd4cca498a0c83bc63)
#         ;
#
#
#
#
#             var circle_marker_340f54a7deb7f2464f896b882d95bd5a = L.circleMarker(
#                 [37.4807172, 126.9882185],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 44.032, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_711b939505f44d2af8a91765b7005a05);
#
#
#         var popup_622d93ff70d4d864cf56def879eb1dff = L.popup({&quot;maxWidth&quot;: 300, &quot;minWidth&quot;: 150});
#
#
#
#                 var html_4de0b70e05e049d7b6abac1a74001916 = $(`&lt;div id=&quot;html_4de0b70e05e049d7b6abac1a74001916&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;도구로(도구머리꽃길)&lt;/b&gt;&lt;br&gt;&lt;br&gt;- 길이 : 0.4km&lt;br&gt;- 사당역 13번출구&lt;br&gt;- 도구머리공원 사잇길을 따라 한적하게 산책하기 좋은 꽃길(산책)&lt;/div&gt;`)[0];
#                 popup_622d93ff70d4d864cf56def879eb1dff.setContent(html_4de0b70e05e049d7b6abac1a74001916);
#
#
#
#         circle_marker_340f54a7deb7f2464f896b882d95bd5a.bindPopup(popup_622d93ff70d4d864cf56def879eb1dff)
#         ;
#
#
#
#
#             var circle_marker_08930f1a92c41bcfaa0bc91207303ccb = L.circleMarker(
#                 [37.533100700000006, 126.9199973],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 38.826, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_711b939505f44d2af8a91765b7005a05);
#
#
#         var popup_c72b2346d43716b6e5dcf2f2608adb7b = L.popup({&quot;maxWidth&quot;: 300, &quot;minWidth&quot;: 150});
#
#
#
#                 var html_838c22f3ba0e79b2ff9cbdc41c3ef3f3 = $(`&lt;div id=&quot;html_838c22f3ba0e79b2ff9cbdc41c3ef3f3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;여의 동·서로(윤중로)&lt;/b&gt;&lt;br&gt;&lt;br&gt;- 길이 : 6.9㎞&lt;br&gt;- 국회의사당역 2번출구&lt;br&gt;- 여의도 국회주변 화려한 벚꽃이 장관을 이루며 매년 ‘한강 여의도 봄꽃축제’ 개최(나들이, 산책)&lt;/div&gt;`)[0];
#                 popup_c72b2346d43716b6e5dcf2f2608adb7b.setContent(html_838c22f3ba0e79b2ff9cbd

# %% [markdown]
# ### 평일 밤

# %%
import folium

map = folium.Map(
    location=[37.534272313844, 126.97534763076],
    zoom_start=12, 
#     tiles='cartodbpositron'
)

for index, row in data_average_weekday.iterrows():
    lat = row['lat']
    long = row['long']
    folium.CircleMarker([lat, long], 
                       radius = row['average_user_cnt_night']/100 + 5,
                       popup = folium.Popup("<b>{}</b><br><br>- 길이 : {}<br>- {} {}번출구<br>- {}".format(row['loc_name'], row['length'], row['final_station'], row['exit_num'], row['feature']), max_width=300, min_width=150),
                       color = "blue",
                       fill = True).add_to(map)
    
map.save('result/map_cherry_blossom_weekday_night.html')

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_03b9792a651213595e2b932587a1a90e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_03b9792a651213595e2b932587a1a90e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_03b9792a651213595e2b932587a1a90e = L.map(
#                 &quot;map_03b9792a651213595e2b932587a1a90e&quot;,
#                 {
#                     center: [37.534272313844, 126.97534763076],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ce2ea8b3eff22418d90ff3c37dfcde72 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_03b9792a651213595e2b932587a1a90e);
#
#
#             var circle_marker_6b3463e1ffca8eb42acf659635c0b324 = L.circleMarker(
#                 [37.506240600000005, 127.09771629999999],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 53.843999999999994, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_03b9792a651213595e2b932587a1a90e);
#
#
#         var popup_90f6400f2c45f634341118338aeff39c = L.popup({&quot;maxWidth&quot;: 300, &quot;minWidth&quot;: 150});
#
#
#
#                 var html_34929eebe8ea6ab1482e43665252362b = $(`&lt;div id=&quot;html_34929eebe8ea6ab1482e43665252362b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;송파나루공원(석촌호수)&lt;/b&gt;&lt;br&gt;&lt;br&gt;- 길이 : 2.5km&lt;br&gt;- 잠실역 3번출구&lt;br&gt;- 석촌호수와 어우러져 피는 벚꽃, 철쭉, 야생화가 아름다움(산책, 운동)&lt;/div&gt;`)[0];
#                 popup_90f6400f2c45f634341118338aeff39c.setContent(html_34929eebe8ea6ab1482e43665252362b);
#
#
#
#         circle_marker_6b3463e1ffca8eb42acf659635c0b324.bindPopup(popup_90f6400f2c45f634341118338aeff39c)
#         ;
#
#
#
#
#             var circle_marker_9131efd36a6119ac9084f0b726fec287 = L.circleMarker(
#                 [37.4807172, 126.9882185],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 50.902, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_03b9792a651213595e2b932587a1a90e);
#
#
#         var popup_191781f0761b24a691c8e3efd13dd78f = L.popup({&quot;maxWidth&quot;: 300, &quot;minWidth&quot;: 150});
#
#
#
#                 var html_82c7893aa0f535353aeada752bd9a7c2 = $(`&lt;div id=&quot;html_82c7893aa0f535353aeada752bd9a7c2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;도구로(도구머리꽃길)&lt;/b&gt;&lt;br&gt;&lt;br&gt;- 길이 : 0.4km&lt;br&gt;- 사당역 13번출구&lt;br&gt;- 도구머리공원 사잇길을 따라 한적하게 산책하기 좋은 꽃길(산책)&lt;/div&gt;`)[0];
#                 popup_191781f0761b24a691c8e3efd13dd78f.setContent(html_82c7893aa0f535353aeada752bd9a7c2);
#
#
#
#         circle_marker_9131efd36a6119ac9084f0b726fec287.bindPopup(popup_191781f0761b24a691c8e3efd13dd78f)
#         ;
#
#
#
#
#             var circle_marker_c8dc562f1d85819882e79c311767cd5a = L.circleMarker(
#                 [37.533100700000006, 126.9199973],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 46.022, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_03b9792a651213595e2b932587a1a90e);
#
#
#         var popup_8a56080616fbc41cefafe47ee373e7b1 = L.popup({&quot;maxWidth&quot;: 300, &quot;minWidth&quot;: 150});
#
#
#
#                 var html_735b6d93bdf25740d0dc97af678fd536 = $(`&lt;div id=&quot;html_735b6d93bdf25740d0dc97af678fd536&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;여의 동·서로(윤중로)&lt;/b&gt;&lt;br&gt;&lt;br&gt;- 길이 : 6.9㎞&lt;br&gt;- 국회의사당역 2번출구&lt;br&gt;- 여의도 국회주변 화려한 벚꽃이 장관을 이루며 매년 ‘한강 여의도 봄꽃축제’ 개최(나들이, 산책)&lt;/div&gt;`)[0];
#                 popup_8a56080616fbc41cefafe47ee373e7b1.setContent(html_735b

# %% [markdown]
# ### 주말 낮

# %%
import folium

map = folium.Map(
    location=[37.534272313844, 126.97534763076],
    zoom_start=12, 
#     tiles='cartodbpositron'
)

for index, row in data_average_weekend.iterrows():
    lat = row['lat']
    long = row['long']
    folium.CircleMarker([lat, long], 
                       radius = row['average_user_cnt_day']/100 + 5,
                       popup = folium.Popup("<b>{}</b><br><br>- 길이 : {}<br>- {} {}번출구<br>- {}".format(row['loc_name'], row['length'], row['final_station'], row['exit_num'], row['feature']), max_width=300, min_width=150),
                       color = "red",
                       fill = True).add_to(map)
    
map.save('result/map_cherry_blossom_weekend_day.html')

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bfad981ba9d21bea9ac850efb0246ac3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bfad981ba9d21bea9ac850efb0246ac3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bfad981ba9d21bea9ac850efb0246ac3 = L.map(
#                 &quot;map_bfad981ba9d21bea9ac850efb0246ac3&quot;,
#                 {
#                     center: [37.534272313844, 126.97534763076],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_385ea4469225f3b5842fbfe1596806de = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_bfad981ba9d21bea9ac850efb0246ac3);
#
#
#             var circle_marker_090bfadb92af55d68332d1bae2d04430 = L.circleMarker(
#                 [37.533100700000006, 126.9199973],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 67.69, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_bfad981ba9d21bea9ac850efb0246ac3);
#
#
#         var popup_a24d9e24527272a6a723acdabb15fd61 = L.popup({&quot;maxWidth&quot;: 300, &quot;minWidth&quot;: 150});
#
#
#
#                 var html_280ea50d7ebbd1942364e11669fe5d12 = $(`&lt;div id=&quot;html_280ea50d7ebbd1942364e11669fe5d12&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;여의 동·서로(윤중로)&lt;/b&gt;&lt;br&gt;&lt;br&gt;- 길이 : 6.9㎞&lt;br&gt;- 국회의사당역 2번출구&lt;br&gt;- 여의도 국회주변 화려한 벚꽃이 장관을 이루며 매년 ‘한강 여의도 봄꽃축제’ 개최(나들이, 산책)&lt;/div&gt;`)[0];
#                 popup_a24d9e24527272a6a723acdabb15fd61.setContent(html_280ea50d7ebbd1942364e11669fe5d12);
#
#
#
#         circle_marker_090bfadb92af55d68332d1bae2d04430.bindPopup(popup_a24d9e24527272a6a723acdabb15fd61)
#         ;
#
#
#
#
#             var circle_marker_fb13ab585e1bc88fcba088ca3059d5c8 = L.circleMarker(
#                 [37.506240600000005, 127.09771629999999],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 58.27, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_bfad981ba9d21bea9ac850efb0246ac3);
#
#
#         var popup_cf23d0e50dd30e98dc8f3a40404248d0 = L.popup({&quot;maxWidth&quot;: 300, &quot;minWidth&quot;: 150});
#
#
#
#                 var html_82cc5c9fbd1a009a51c86b27add293e1 = $(`&lt;div id=&quot;html_82cc5c9fbd1a009a51c86b27add293e1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;송파나루공원(석촌호수)&lt;/b&gt;&lt;br&gt;&lt;br&gt;- 길이 : 2.5km&lt;br&gt;- 잠실역 3번출구&lt;br&gt;- 석촌호수와 어우러져 피는 벚꽃, 철쭉, 야생화가 아름다움(산책, 운동)&lt;/div&gt;`)[0];
#                 popup_cf23d0e50dd30e98dc8f3a40404248d0.setContent(html_82cc5c9fbd1a009a51c86b27add293e1);
#
#
#
#         circle_marker_fb13ab585e1bc88fcba088ca3059d5c8.bindPopup(popup_cf23d0e50dd30e98dc8f3a40404248d0)
#         ;
#
#
#
#
#             var circle_marker_5ba5ec6c5de23df11e8fe6ca68dc21c9 = L.circleMarker(
#                 [37.4807172, 126.9882185],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 51.375, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_bfad981ba9d21bea9ac850efb0246ac3);
#
#
#         var popup_ac2a3534aaad5fcf4c0d1bfb1219015a = L.popup({&quot;maxWidth&quot;: 300, &quot;minWidth&quot;: 150});
#
#
#
#                 var html_694a26b6907a4ba208a10a25ab226ce5 = $(`&lt;div id=&quot;html_694a26b6907a4ba208a10a25ab226ce5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;도구로(도구머리꽃길)&lt;/b&gt;&lt;br&gt;&lt;br&gt;- 길이 : 0.4km&lt;br&gt;- 사당역 13번출구&lt;br&gt;- 도구머리공원 사잇길을 따라 한적하게 산책하기 좋은 꽃길(산책)&lt;/div&gt;`)[0];
#                 popup_ac2a3534aaad5fcf4c0d1bfb1219015a.setContent(html_694a26b6907a4ba208a10a25

# %% [markdown]
# ### 주말 밤

# %%
import folium

map = folium.Map(
    location=[37.534272313844, 126.97534763076],
    zoom_start=12, 
#     tiles='cartodbpositron'
)

for index, row in data_average_weekend.iterrows():
    lat = row['lat']
    long = row['long']
    folium.CircleMarker([lat, long], 
                       radius = row['average_user_cnt_night']/100 + 5,
                       popup = folium.Popup("<b>{}</b><br><br>- 길이 : {}<br>- {} {}번출구<br>- {}".format(row['loc_name'], row['length'], row['final_station'], row['exit_num'], row['feature']), max_width=300, min_width=150),
                       color = "blue",
                       fill = True).add_to(map)
    
map.save('result/map_cherry_blossom_weekend_night.html')

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_04faf6353888b0ed63edd77499a1640a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_04faf6353888b0ed63edd77499a1640a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_04faf6353888b0ed63edd77499a1640a = L.map(
#                 &quot;map_04faf6353888b0ed63edd77499a1640a&quot;,
#                 {
#                     center: [37.534272313844, 126.97534763076],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f2fb6639a51f3dabc081e5850c14a722 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_04faf6353888b0ed63edd77499a1640a);
#
#
#             var circle_marker_739baea857161378083b042524f9c6ef = L.circleMarker(
#                 [37.533100700000006, 126.9199973],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 78.715, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_04faf6353888b0ed63edd77499a1640a);
#
#
#         var popup_b4d9465a7bc2ddfa2f67411523145cbf = L.popup({&quot;maxWidth&quot;: 300, &quot;minWidth&quot;: 150});
#
#
#
#                 var html_d68d049cf4ef95b2a6b7feeddb4744bd = $(`&lt;div id=&quot;html_d68d049cf4ef95b2a6b7feeddb4744bd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;여의 동·서로(윤중로)&lt;/b&gt;&lt;br&gt;&lt;br&gt;- 길이 : 6.9㎞&lt;br&gt;- 국회의사당역 2번출구&lt;br&gt;- 여의도 국회주변 화려한 벚꽃이 장관을 이루며 매년 ‘한강 여의도 봄꽃축제’ 개최(나들이, 산책)&lt;/div&gt;`)[0];
#                 popup_b4d9465a7bc2ddfa2f67411523145cbf.setContent(html_d68d049cf4ef95b2a6b7feeddb4744bd);
#
#
#
#         circle_marker_739baea857161378083b042524f9c6ef.bindPopup(popup_b4d9465a7bc2ddfa2f67411523145cbf)
#         ;
#
#
#
#
#             var circle_marker_c31b9c713089c367a1232af1f04c37e1 = L.circleMarker(
#                 [37.506240600000005, 127.09771629999999],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 63.69, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_04faf6353888b0ed63edd77499a1640a);
#
#
#         var popup_bf05f1a1b8060d77d062d4e68cda8d64 = L.popup({&quot;maxWidth&quot;: 300, &quot;minWidth&quot;: 150});
#
#
#
#                 var html_6940bc03974c09964992c6c197b467dd = $(`&lt;div id=&quot;html_6940bc03974c09964992c6c197b467dd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;송파나루공원(석촌호수)&lt;/b&gt;&lt;br&gt;&lt;br&gt;- 길이 : 2.5km&lt;br&gt;- 잠실역 3번출구&lt;br&gt;- 석촌호수와 어우러져 피는 벚꽃, 철쭉, 야생화가 아름다움(산책, 운동)&lt;/div&gt;`)[0];
#                 popup_bf05f1a1b8060d77d062d4e68cda8d64.setContent(html_6940bc03974c09964992c6c197b467dd);
#
#
#
#         circle_marker_c31b9c713089c367a1232af1f04c37e1.bindPopup(popup_bf05f1a1b8060d77d062d4e68cda8d64)
#         ;
#
#
#
#
#             var circle_marker_2f461882cb041baecab8e7cc5fbb17a6 = L.circleMarker(
#                 [37.4807172, 126.9882185],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 42.41, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_04faf6353888b0ed63edd77499a1640a);
#
#
#         var popup_a258ca931241fe3528e9339c6f20dbfc = L.popup({&quot;maxWidth&quot;: 300, &quot;minWidth&quot;: 150});
#
#
#
#                 var html_a3c53f0c07c3703520e12ee39374506d = $(`&lt;div id=&quot;html_a3c53f0c07c3703520e12ee39374506d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;도구로(도구머리꽃길)&lt;/b&gt;&lt;br&gt;&lt;br&gt;- 길이 : 0.4km&lt;br&gt;- 사당역 13번출구&lt;br&gt;- 도구머리공원 사잇길을 따라 한적하게 산책하기 좋은 꽃길(산책)&lt;/div&gt;`)[0];
#                 popup_a258ca931241fe3528e9339c6f20dbfc.setContent(html_a3c53f0c07c3703520
